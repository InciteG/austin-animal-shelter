# %%
arr_one = ['A', 'B', 'C', 'D', 'E']   ## list 1
arr_two = ['X', 'Y', 'Z', 'W', 'Q', 'L'] ## list 2
arr_comb = set(arr_one+arr_two)

comb = []
for i in arr_comb:
    ele1 = i
    if ele1 in arr_one:
        for x in arr_two:
            ele2 = x
            
            for y in arr_comb:
                ele3 = y
                for z in arr_comb:
                    ele4 = z
                    ele= ''.join([ele1,ele2,ele3,ele4])
                    comb.append(ele)
                    
    else:
        for x in arr_one:
            ele2 = x
            for y in arr_comb:
                ele3 = y
                for z in arr_comb:
                    ele4 = z
                    ele= ''.join([ele1,ele2,ele3,ele4])
                    comb.append(ele)

        
comb
# Out:
# ['AXAA',
#  'AXAL',
#  'AXAX',
#  'AXAE',
#  'AXAZ',
#  'AXAC',
#  'AXAW',
#  'AXAY',
#  'AXAQ',
#  'AXAD',
#  'AXAB',
#  'AXLA',
#  'AXLL',
#  'AXLX',
#  'AXLE',
#  'AXLZ',
#  'AXLC',
#  'AXLW',
#  'AXLY',
#  'AXLQ',
#  'AXLD',
#  'AXLB',
#  'AXXA',
#  'AXXL',
#  'AXXX',
#  'AXXE',
#  'AXXZ',
#  'AXXC',
#  'AXXW',
#  'AXXY',
#  'AXXQ',
#  'AXXD',
#  'AXXB',
#  'AXEA',
#  'AXEL',
#  'AXEX',
#  'AXEE',
#  'AXEZ',
#  'AXEC',
#  'AXEW',
#  'AXEY',
#  'AXEQ',
#  'AXED',
#  'AXEB',
#  'AXZA',
#  'AXZL',
#  'AXZX',
#  'AXZE',
#  'AXZZ',
#  'AXZC',
#  'AXZW',
#  'AXZY',
#  'AXZQ',
#  'AXZD',
#  'AXZB',
#  'AXCA',
#  'AXCL',
#  'AXCX',
#  'AXCE',
#  'AXCZ',
#  'AXCC',
#  'AXCW',
#  'AXCY',
#  'AXCQ',
#  'AXCD',
#  'AXCB',
#  'AXWA',
#  'AXWL',
#  'AXWX',
#  'AXWE',
#  'AXWZ',
#  'AXWC',
#  'AXWW',
#  'AXWY',
#  'AXWQ',
#  'AXWD',
#  'AXWB',
#  'AXYA',
#  'AXYL',
#  'AXYX',
#  'AXYE',
#  'AXYZ',
#  'AXYC',
#  'AXYW',
#  'AXYY',
#  'AXYQ',
#  'AXYD',
#  'AXYB',
#  'AXQA',
#  'AXQL',
# ...

# %%
len(comb)
# Out:
# 7260
